# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ocessing Record 28 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 4 | turukhansk
# Processing Record 30 of Set 4 | cayambe
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | krasnoselkup
# Processing Record 33 of Set 4 | vilhena
# Processing Record 34 of Set 4 | shingu
# Processing Record 35 of Set 4 | mahajanga
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | kaeo
# Processing Record 40 of Set 4 | bafq
# Processing Record 41 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 4 | tongling
# Processing Record 43 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | maple valley
# Processing Record 47 of Set 4 | sobolevo
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | berlevag
# Processing Record 0 of Set 5 | yeniseysk
# Processing Record 1 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 5 | talcahuano
# Processing Record 3 of Set 5 | san policarpo
# Processing Record 4 of Set 5 | ilam
# Processing Record 5 of Set 5 | porto walter
# Processing Record 6 of Set 5 | saint quentin
# City not found. Skipping...
# Processing Record 7 of Set 5 | provideniya
# Processing Record 8 of Set 5 | odweyne
# Processing Record 9 of Set 5 | wagar
# Processing Record 10 of Set 5 | alihe
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | mecca
# Processing Record 13 of Set 5 | khromtau
# Processing Record 14 of Set 5 | slavonice
# Processing Record 15 of Set 5 | chinhoyi
# Processing Record 16 of Set 5 | bredasdorp
# Processing Record 17 of Set 5 | tessalit
# Processing Record 18 of Set 5 | kutum
# Processing Record 19 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 5 | kuusankoski
# Processing Record 21 of Set 5 | santa luzia
# Processing Record 22 of Set 5 | malanje
# Processing Record 23 of Set 5 | ossora
# Processing Record 24 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 5 | ternate
# Processing Record 26 of Set 5 | dubbo
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | chapais
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | porto velho
# Processing Record 31 of Set 5 | hoyerswerda
# Processing Record 32 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 5 | sinnamary
# Processing Record 34 of Set 5 | damaturu
# Processing Record 35 of Set 5 | leh
# Processing Record 36 of Set 5 | jalapa
# Processing Record 37 of Set 5 | sisimiut
# Processing Record 38 of Set 5 | hobyo
# Processing Record 39 of Set 5 | gamba
# Processing Record 40 of Set 5 | mutoko
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | samarai
# Processing Record 44 of Set 5 | tautira
# Processing Record 45 of Set 5 | kawalu
# Processing Record 46 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 47 of Set 5 | delmas
# Processing Record 48 of Set 5 | nador
# Processing Record 49 of Set 5 | batangafo
# Processing Record 0 of Set 6 | airai
# Processing Record 1 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 6 | tel aviv-yafo
# Processing Record 3 of Set 6 | grand-santi
# Processing Record 4 of Set 6 | rongcheng
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | opuwo
# Processing Record 7 of Set 6 | tofield
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | baracatan
# Processing Record 10 of Set 6 | tateyama
# Processing Record 11 of Set 6 | pinawa
# Processing Record 12 of Set 6 | itoman
# Processing Record 13 of Set 6 | cajamarca
# Processing Record 14 of Set 6 | sergeyevka
# Processing Record 15 of Set 6 | nampula
# Processing Record 16 of Set 6 | hamilton
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | port said
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | segamat
# Processing Record 21 of Set 6 | chaohu
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | camacupa
# Processing Record 25 of Set 6 | viesca
# Processing Record 26 of Set 6 | baiyin
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | podgorenskiy
# Processing Record 30 of Set 6 | dunedin
# Processing Record 31 of Set 6 | yokadouma
# Processing Record 32 of Set 6 | ibra
# Processing Record 33 of Set 6 | huangnihe
# Processing Record 34 of Set 6 | serenje
# Processing Record 35 of Set 6 | vostok
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | grand gaube
# Processing Record 38 of Set 6 | orlik
# Processing Record 39 of Set 6 | igarka
# Processing Record 40 of Set 6 | okhotsk
# Processing Record 41 of Set 6 | marsa matruh
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | englehart
# Processing Record 44 of Set 6 | east london
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | pangai
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 0 of Set 7 | hambantota
# Processing Record 1 of Set 7 | corumba
# Processing Record 2 of Set 7 | gizo
# Processing Record 3 of Set 7 | loandjili
# Processing Record 4 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 7 | morant bay
# Processing Record 6 of Set 7 | imeni poliny osipenko
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | umm lajj
# Processing Record 9 of Set 7 | blythe
# Processing Record 10 of Set 7 | biak
# Processing Record 11 of Set 7 | randfontein
# Processing Record 12 of Set 7 | mazatlan
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | menongue
# Processing Record 15 of Set 7 | saint-pierre
# Processing Record 16 of Set 7 | dukat
# Processing Record 17 of Set 7 | constitucion
# Processing Record 18 of Set 7 | oksbol
# Processing Record 19 of Set 7 | villa bruzual
# Processing Record 20 of Set 7 | puteyets
# Processing Record 21 of Set 7 | svetlyy
# Processing Record 22 of Set 7 | jacareacanga
# Processing Record 23 of Set 7 | tubuala
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | coahuayana
# Processing Record 27 of Set 7 | fereydunshahr
# Processing Record 28 of Set 7 | altay
# Processing Record 29 of Set 7 | hasaki
# Processing Record 30 of Set 7 | mandan
# Processing Record 31 of Set 7 | nhulunbuy
# Processing Record 32 of Set 7 | brahmapuri
# City not found. Skipping...
# Processing Record 33 of Set 7 | jieshi
# Processing Record 34 of Set 7 | norwalk
# Processing Record 35 of Set 7 | greystones
# Processing Record 36 of Set 7 | rio grande
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | faya
# Processing Record 39 of Set 7 | coquimbo
# Processing Record 40 of Set 7 | sinazongwe
# Processing Record 41 of Set 7 | teahupoo
# Processing Record 42 of Set 7 | almaty
# Processing Record 43 of Set 7 | bose
# Processing Record 44 of Set 7 | general cepeda
# Processing Record 45 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 7 | lebanon
# Processing Record 47 of Set 7 | beyneu
# Processing Record 48 of Set 7 | konch
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 0 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 1 of Set 8 | benghazi
# Processing Record 2 of Set 8 | te anau
# Processing Record 3 of Set 8 | arlit
# Processing Record 4 of Set 8 | chumphon
# Processing Record 5 of Set 8 | yatou
# Processing Record 6 of Set 8 | jardim
# Processing Record 7 of Set 8 | vulcan
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | tuy hoa
# Processing Record 10 of Set 8 | zaysan
# Processing Record 11 of Set 8 | urucara
# Processing Record 12 of Set 8 | prince george
# Processing Record 13 of Set 8 | praia
# Processing Record 14 of Set 8 | bambanglipuro
# Processing Record 15 of Set 8 | zhigansk
# Processing Record 16 of Set 8 | orchard homes
# Processing Record 17 of Set 8 | portland
# Processing Record 18 of Set 8 | pacific grove
# Processing Record 19 of Set 8 | tulsipur
# Processing Record 20 of Set 8 | laizhou
# Processing Record 21 of Set 8 | nikolayevka
# Processing Record 22 of Set 8 | lumeje
# Processing Record 23 of Set 8 | saldanha
# Processing Record 24 of Set 8 | aykhal
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | etchoropo
# Processing Record 27 of Set 8 | puerto madero
# Processing Record 28 of Set 8 | storforshei
# Processing Record 29 of Set 8 | iberia
# Processing Record 30 of Set 8 | northam
# Processing Record 31 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 8 | copala
# Processing Record 33 of Set 8 | leshukonskoye
# Processing Record 34 of Set 8 | pirgos
# Processing Record 35 of Set 8 | oktyabrskoye
# Processing Record 36 of Set 8 | banjar
# Processing Record 37 of Set 8 | batagay-alyta
# Processing Record 38 of Set 8 | barra do garcas
# Processing Record 39 of Set 8 | bandarbeyla
# Processing Record 40 of Set 8 | evensk
# Processing Record 41 of Set 8 | killybegs
# Processing Record 42 of Set 8 | bima
# Processing Record 43 of Set 8 | zyryanka
# Processing Record 44 of Set 8 | nacala
# Processing Record 45 of Set 8 | cairns
# Processing Record 46 of Set 8 | mandla
# Processing Record 47 of Set 8 | port augusta
# Processing Record 48 of Set 8 | havelock
# Processing Record 49 of Set 8 | ploemeur
# Processing Record 0 of Set 9 | renkum
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | ilorin
# Processing Record 3 of Set 9 | berbera
# Processing Record 4 of Set 9 | kysyl-syr
# Processing Record 5 of Set 9 | yablochnyy
# Processing Record 6 of Set 9 | mildura
# Processing Record 7 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 9 | poum
# Processing Record 9 of Set 9 | richmond
# Processing Record 10 of Set 9 | sheregesh
# Processing Record 11 of Set 9 | redmond
# Processing Record 12 of Set 9 | balabac
# Processing Record 13 of Set 9 | ermoupolis
# Processing Record 14 of Set 9 | huaihua
# Processing Record 15 of Set 9 | sakakah
# Processing Record 16 of Set 9 | prado
# Processing Record 17 of Set 9 | sabaudia
# Processing Record 18 of Set 9 | roma
# Processing Record 19 of Set 9 | rudbar
# Processing Record 20 of Set 9 | moers
# Processing Record 21 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 9 | hastings
# Processing Record 23 of Set 9 | ahipara
# Processing Record 24 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 9 | coolum beach
# Processing Record 26 of Set 9 | raudeberg
# Processing Record 27 of Set 9 | jalu
# Processing Record 28 of Set 9 | keti bandar
# Processing Record 29 of Set 9 | orsay
# Processing Record 30 of Set 9 | grindavik
# Processing Record 31 of Set 9 | pisco
# Processing Record 32 of Set 9 | zamberk
# Processing Record 33 of Set 9 | rawson
# Processing Record 34 of Set 9 | necochea
# Processing Record 35 of Set 9 | pangody
# Processing Record 36 of Set 9 | christchurch
# Processing Record 37 of Set 9 | tommot
# Processing Record 38 of Set 9 | mashhad
# Processing Record 39 of Set 9 | houston
# Processing Record 40 of Set 9 | makakilo city
# Processing Record 41 of Set 9 | inveraray
# City not found. Skipping...
# Processing Record 42 of Set 9 | deputatskiy
# Processing Record 43 of Set 9 | kamiiso
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | waddan
# Processing Record 46 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 9 | guanica
# Processing Record 48 of Set 9 | dorado
# Processing Record 49 of Set 9 | oudtshoorn
# Processing Record 0 of Set 10 | tambun
# Processing Record 1 of Set 10 | mongo
# Processing Record 2 of Set 10 | vitim
# Processing Record 3 of Set 10 | clyde river
# Processing Record 4 of Set 10 | tongzi
# Processing Record 5 of Set 10 | saint-louis
# Processing Record 6 of Set 10 | bryan
# Processing Record 7 of Set 10 | fairbanks
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | mandalay
# Processing Record 10 of Set 10 | paramonga
# Processing Record 11 of Set 10 | magaria
# Processing Record 12 of Set 10 | dothan
# Processing Record 13 of Set 10 | ankpa
# Processing Record 14 of Set 10 | cidreira
# Processing Record 15 of Set 10 | chudovo
# Processing Record 16 of Set 10 | dolores
# Processing Record 17 of Set 10 | forssa
# Processing Record 18 of Set 10 | karakol
# Processing Record 19 of Set 10 | marsaxlokk
# Processing Record 20 of Set 10 | graaff-reinet
# Processing Record 21 of Set 10 | metlika
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | shakawe
# Processing Record 24 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 10 | viedma
# Processing Record 26 of Set 10 | itarema
# Processing Record 27 of Set 10 | awjilah
# Processing Record 28 of Set 10 | kashi
# Processing Record 29 of Set 10 | shizunai
# Processing Record 30 of Set 10 | show low
# Processing Record 31 of Set 10 | tondano
# Processing Record 32 of Set 10 | haicheng
# Processing Record 33 of Set 10 | kisujszallas
# Processing Record 34 of Set 10 | sayyan
# Processing Record 35 of Set 10 | mach
# Processing Record 36 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 10 | lluta
# Processing Record 38 of Set 10 | baiquan
# Processing Record 39 of Set 10 | ternovka
# Processing Record 40 of Set 10 | kousseri
# Processing Record 41 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 10 | dakar
# Processing Record 43 of Set 10 | mwinilunga
# Processing Record 44 of Set 10 | perambalur
# Processing Record 45 of Set 10 | los llanos de aridane
# Processing Record 46 of Set 10 | preetz
# Processing Record 47 of Set 10 | aklavik
# Processing Record 48 of Set 10 | davila
# Processing Record 49 of Set 10 | rupert
# Processing Record 0 of Set 11 | kununurra
# Processing Record 1 of Set 11 | havelian
# Processing Record 2 of Set 11 | mayahi
# Processing Record 3 of Set 11 | la grande
# Processing Record 4 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 11 | axim
# Processing Record 6 of Set 11 | yulara
# Processing Record 7 of Set 11 | terney
# Processing Record 8 of Set 11 | pacifica
# Processing Record 9 of Set 11 | finschhafen
# Processing Record 10 of Set 11 | ulaanbaatar
# Processing Record 11 of Set 11 | kenora
# Processing Record 12 of Set 11 | ahuimanu
# Processing Record 13 of Set 11 | xichang
# Processing Record 14 of Set 11 | nzerekore
# Processing Record 15 of Set 11 | ajdabiya
# Processing Record 16 of Set 11 | road town
# Processing Record 17 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 11 | vanavara
# Processing Record 19 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 11 | manthani
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | taoudenni
# Processing Record 23 of Set 11 | glasgow
# Processing Record 24 of Set 11 | gat
# Processing Record 25 of Set 11 | burnie
# Processing Record 26 of Set 11 | asau
# Processing Record 27 of Set 11 | uyuni
# Processing Record 28 of Set 11 | vylkove
# Processing Record 29 of Set 11 | bogorodskoye
# Processing Record 30 of Set 11 | baykalovo
# Processing Record 31 of Set 11 | ishigaki
# Processing Record 32 of Set 11 | solnechnyy
# Processing Record 33 of Set 11 | progreso
# Processing Record 34 of Set 11 | port hedland
# Processing Record 35 of Set 11 | bosaso
# Processing Record 36 of Set 11 | culaman
# Processing Record 37 of Set 11 | valparaiso
# Processing Record 38 of Set 11 | lima
# Processing Record 39 of Set 11 | tocopilla
# Processing Record 40 of Set 11 | marienburg
# Processing Record 41 of Set 11 | bagn
# Processing Record 42 of Set 11 | nabire
# Processing Record 43 of Set 11 | mbini
# Processing Record 44 of Set 11 | bayan
# Processing Record 45 of Set 11 | mao
# Processing Record 46 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 11 | haverhill
# Processing Record 48 of Set 11 | saint-jean-de-luz
# Processing Record 49 of Set 11 | clausthal-zellerfeld
# Processing Record 0 of Set 12 | banda aceh
# Processing Record 1 of Set 12 | superior
# Processing Record 2 of Set 12 | maraba
# Processing Record 3 of Set 12 | avera
# Processing Record 4 of Set 12 | aranos
# Processing Record 5 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 6 of Set 12 | bogovarovo
# Processing Record 7 of Set 12 | novoagansk
# Processing Record 8 of Set 12 | poya
# Processing Record 9 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 12 | okakarara
# Processing Record 11 of Set 12 | ust-nera
# Processing Record 12 of Set 12 | campbell river
# Processing Record 13 of Set 12 | tamandare
# Processing Record 14 of Set 12 | yeppoon
# Processing Record 15 of Set 12 | charters towers
# Processing Record 16 of Set 12 | genhe
# Processing Record 17 of Set 12 | tadine
# Processing Record 18 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 12 | eenhana
# Processing Record 20 of Set 12 | shache
# Processing Record 21 of Set 12 | trincomalee
# Processing Record 22 of Set 12 | warren
# Processing Record 23 of Set 12 | moose factory
# Processing Record 24 of Set 12 | gamboula
# Processing Record 25 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 12 | ambon
# Processing Record 27 of Set 12 | sarvar
# Processing Record 28 of Set 12 | comodoro rivadavia
# Processing Record 29 of Set 12 | nisia floresta
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | heidenau
# Processing Record 32 of Set 12 | pahrump
# Processing Record 33 of Set 12 | neryungri
# Processing Record 34 of Set 12 | bintulu
# Processing Record 35 of Set 12 | narimanov
# Processing Record 36 of Set 12 | siavonga
# Processing Record 37 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 12 | olafsvik
# Processing Record 39 of Set 12 | buala
# Processing Record 40 of Set 12 | bubaque
# Processing Record 41 of Set 12 | sfantu gheorghe
# Processing Record 42 of Set 12 | stulovo
# Processing Record 43 of Set 12 | kiama
# Processing Record 44 of Set 12 | guasdualito
# Processing Record 45 of Set 12 | matara
# Processing Record 46 of Set 12 | tyukalinsk
# Processing Record 47 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 48 of Set 12 | linqiong
# Processing Record 49 of Set 12 | dodge city
# Processing Record 0 of Set 13 | griffith
# Processing Record 1 of Set 13 | puerto madryn
# Processing Record 2 of Set 13 | tiruchchendur
# Processing Record 3 of Set 13 | husavik
# Processing Record 4 of Set 13 | inirida
# Processing Record 5 of Set 13 | vermilion
# Processing Record 6 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 13 | mkushi
# Processing Record 8 of Set 13 | nhamunda
# Processing Record 9 of Set 13 | padang
# Processing Record 10 of Set 13 | anloga
# Processing Record 11 of Set 13 | goderich
# Processing Record 12 of Set 13 | iskateley
# Processing Record 13 of Set 13 | sezana
# Processing Record 14 of Set 13 | kavaratti
# Processing Record 15 of Set 13 | noumea
# Processing Record 16 of Set 13 | bereda
# Processing Record 17 of Set 13 | sharjah
# Processing Record 18 of Set 13 | burica
# City not found. Skipping...
# Processing Record 19 of Set 13 | plettenberg bay
# Processing Record 20 of Set 13 | coyuca
# City not found. Skipping...
# Processing Record 21 of Set 13 | isangel
# Processing Record 22 of Set 13 | smithers
# Processing Record 23 of Set 13 | marquette
# Processing Record 24 of Set 13 | zomin
# Processing Record 25 of Set 13 | yuzawa
# Processing Record 26 of Set 13 | grass valley
# Processing Record 27 of Set 13 | sept-iles
# Processing Record 28 of Set 13 | leningradskiy
# Processing Record 29 of Set 13 | zapolyarnyy
# Processing Record 30 of Set 13 | fort nelson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       bijie  27.31  105.29     73.92        74          99        5.53
# 1      mehamn  71.04   27.85     42.78        87          98       21.54
# 2  butaritari   3.07  172.79     83.59        76          97       11.07
# 3     qaanaaq  77.48  -69.36     29.82        89           0        2.75
# 4     ushuaia -54.80  -68.30     28.40       100          75       18.34
#
#   Country        Date
# 0      CN  1591844558
# 1      NO  1591844559
# 2      KI  1591844559
# 3      GL  1591844559
# 4      AR  1591844560

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
 # OPTIONAL: Create a function to create Linear Regression plots

import scipy.stats as stats

def Lin_Reg(latitude, variable):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, variable)
    regress_values = latitude * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(latitude, variable)
    plt.plot(latitude,regress_values,"r-")
    
    # The annotate is weird with the xy values, just made it so it sits top right
    plt.annotate(line_eq,(max(latitude)-20,max(variable)-10),fontsize=15,color="red")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-squared is: -0.784093623643254

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.64464677145916

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.05966721181190062

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.1626160294697865

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.07939835621128027

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.13960563446090307

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.10321548137176503

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.08680688884832657

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
